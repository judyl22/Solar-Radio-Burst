# %%
import pyspedas
from pytplot import tplot, tplot_names, options, get_data

# %%
# example of a Type III radio burst

trange = ['2019-04-02/15:30', '2019-04-02/16:00']
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_hfr', level='l3')
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_lfr', level='l3')
tplot('psp_fld_l3_rfs_?fr_PSD_FLUX')
# Out:
# 08-Jul-24 15:10:55: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2019/
# 08-Jul-24 15:10:55: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2019/psp_fld_l3_rfs_hfr_20190402_v03.cdf to psp_data/fields/l3/rfs_hfr/2019/psp_fld_l3_rfs_hfr_20190402_v03.cdf
# 08-Jul-24 15:11:11: Download complete: psp_data/fields/l3/rfs_hfr/2019/psp_fld_l3_rfs_hfr_20190402_v03.cdf
# 08-Jul-24 15:11:14: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2019/
# 08-Jul-24 15:11:15: File is current: psp_data/fields/l3/rfs_hfr/2019/psp_fld_l3_rfs_hfr_20190402_v03.cdf
# 08-Jul-24 15:11:15: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2019/
# 08-Jul-24 15:11:16: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2019/psp_fld_l3_rfs_lfr_20190402_v03.cdf to psp_data/fields/l3/rfs_lfr/2019/psp_fld_l3_rfs_lfr_20190402_v03.cdf
# 08-Jul-24 15:11:35: Download complete: psp_data/fields/l3/rfs_lfr/2019/psp_fld_l3_rfs_lfr_20190402_v03.cdf
# 08-Jul-24 15:11:39: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2019/
# 08-Jul-24 15:11:40: File is current: psp_data/fields/l3/rfs_lfr/2019/psp_fld_l3_rfs_lfr_20190402_v03.cdf
# 08-Jul-24 15:11:40: /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(

# %%
# Jovian emission (polarized)

trange = ['2019-09-09/11:00', '2019-09-09/19:00']
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_hfr', level='l3')
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_lfr', level='l3')
tplot(['psp_fld_l3_rfs_hfr_PSD_FLUX','psp_fld_l3_rfs_hfr_STOKES_V'])
# Out:
# 08-Jul-24 15:12:05: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2019/
# 08-Jul-24 15:12:06: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2019/psp_fld_l3_rfs_hfr_20190909_v03.cdf to psp_data/fields/l3/rfs_hfr/2019/psp_fld_l3_rfs_hfr_20190909_v03.cdf
# 08-Jul-24 15:12:17: Download complete: psp_data/fields/l3/rfs_hfr/2019/psp_fld_l3_rfs_hfr_20190909_v03.cdf
# 08-Jul-24 15:12:20: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2019/
# 08-Jul-24 15:12:20: File is current: psp_data/fields/l3/rfs_hfr/2019/psp_fld_l3_rfs_hfr_20190909_v03.cdf
# 08-Jul-24 15:12:20: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2019/
# 08-Jul-24 15:12:21: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2019/psp_fld_l3_rfs_lfr_20190909_v03.cdf to psp_data/fields/l3/rfs_lfr/2019/psp_fld_l3_rfs_lfr_20190909_v03.cdf
# 08-Jul-24 15:12:33: Download complete: psp_data/fields/l3/rfs_lfr/2019/psp_fld_l3_rfs_lfr_20190909_v03.cdf
# 08-Jul-24 15:12:37: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2019/
# 08-Jul-24 15:12:37: File is current: psp_data/fields/l3/rfs_lfr/2019/psp_fld_l3_rfs_lfr_20190909_v03.cdf

# %%
# during a rotation

trange = ['2020-08-05/12:00', '2020-08-05/20:00']
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_hfr', level='l3')
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_lfr', level='l3')

options('psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2', 'zrange', [1e-17,5e-17])
options('psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2', 'zrange', [1e-17,5e-17])

tplot(['psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2','psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2','psp_fld_l3_rfs_lfr_ch0_V1V2_J2000'])
# Out:
# 08-Jul-24 15:15:45: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2020/
# 08-Jul-24 15:15:45: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2020/psp_fld_l3_rfs_hfr_20200805_v03.cdf to psp_data/fields/l3/rfs_hfr/2020/psp_fld_l3_rfs_hfr_20200805_v03.cdf
# 08-Jul-24 15:15:46: Download complete: psp_data/fields/l3/rfs_hfr/2020/psp_fld_l3_rfs_hfr_20200805_v03.cdf
# 08-Jul-24 15:15:50: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2020/
# 08-Jul-24 15:15:51: File is current: psp_data/fields/l3/rfs_hfr/2020/psp_fld_l3_rfs_hfr_20200805_v03.cdf
# 08-Jul-24 15:15:51: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2020/
# 08-Jul-24 15:15:51: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2020/psp_fld_l3_rfs_lfr_20200805_v03.cdf to psp_data/fields/l3/rfs_lfr/2020/psp_fld_l3_rfs_lfr_20200805_v03.cdf
# 08-Jul-24 15:15:53: Download complete: psp_data/fields/l3/rfs_lfr/2020/psp_fld_l3_rfs_lfr_20200805_v03.cdf
# 08-Jul-24 15:15:58: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2020/
# 08-Jul-24 15:15:58: File is current: psp_data/fields/l3/rfs_lfr/2020/psp_fld_l3_rfs_lfr_20200805_v03.cdf

# %%
# near perihelion

trange = ['2023-09-27/12:00', '2023-09-28/12:00']
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_hfr', level='l3')
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_lfr', level='l3')

options('psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2', 'zrange', [1e-16,1e-13])
options('psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2', 'zrange', [1e-16,1e-13])

tplot(['psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2','psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2','psp_fld_l3_rfs_lfr_solar_distance'])
# Out:
# 08-Jul-24 15:37:49: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 08-Jul-24 15:37:50: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20230927_v03.cdf
# 08-Jul-24 15:37:50: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20230928_v03.cdf
# 08-Jul-24 15:37:57: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 08-Jul-24 15:37:58: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20230927_v03.cdf
# 08-Jul-24 15:37:58: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20230928_v03.cdf
# 08-Jul-24 15:37:58: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 08-Jul-24 15:37:59: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20230927_v03.cdf
# 08-Jul-24 15:37:59: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20230928_v03.cdf
# 08-Jul-24 15:38:09: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 08-Jul-24 15:38:09: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20230927_v03.cdf
# 08-Jul-24 15:38:10: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20230928_v03.cdf

# %%
# List all RFS variables

tplot_names()
# Out:
# 0 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2
# 1 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_flux
# 2 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_gain
# 3 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_nsum
# 4 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_hl
# 5 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4
# 6 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_flux
# 7 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_gain
# 8 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_nsum
# 9 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_hl
# 10 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2
# 11 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_flux
# 12 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_gain
# 13 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_nsum
# 14 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_hl
# 15 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4
# 16 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_flux
# 17 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_gain
# 18 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_nsum
# 19 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_hl
# 20 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4
# 21 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_flux
# 22 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_gain
# 23 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_nsum
# 24 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_hl
# 25 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4
# 26 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_flux
# 27 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_gain
# 28 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_nsum
# 29 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_hl
# 30 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4
# 31 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_gain
# 32 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_nsum
# 33 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_hl
# 34 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4
# 35 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_gain
# 36 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_nsum
# 37 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_hl
# 38 : psp_fld_l3_rfs_hfr_ch0_V1V2_RTN
# 39 : psp_fld_l3_rfs_hfr_ch0_V1V2_J2000
# 40 : psp_fld_l3_rfs_hfr_ch0_V1V2_IAU_JUPITER
# 41 : psp_fld_l3_rfs_hfr_ch0_V1V2_bias
# 42 : psp_fld_l3_rfs_hfr_ch1_V3V4_RTN
# 43 : psp_fld_l3_rfs_hfr_ch1_V3V4_J2000
# 44 : psp_fld_l3_rfs_hfr_ch1_V3V4_IAU_JUPITER
# 45 : psp_fld_l3_rfs_hfr_ch1_V3V4_bias
# 46 : psp_fld_l3_rfs_hfr_solar_distance
# 47 : psp_fld_l3_rfs_hfr_position_HAE
# 48 : psp_fld_l3_rfs_hfr_position_HCI
# 49 : psp_fld_l3_rfs_hfr_position_HEE
# 50 : psp_fld_l3_rfs_hfr_position_HEEQ
# 51 : psp_fld_l3_rfs_hfr_position_HG
# 52 : psp_fld_l3_rfs_hfr_position_IAU_JUPITER
# 53 : psp_fld_l3_rfs_hfr_position_RTN
# 54 : psp_fld_l3_rfs_hfr_temperature_PA1
# 55 : psp_fld_l3_rfs_hfr_temperature_PA2
# 56 : psp_fld_l3_rfs_hfr_temperature_PA3
# 57 : psp_fld_l3_rfs_hfr_temperature_PA4
# 58 : psp_fld_l3_rfs_hfr_temperature_DCB
# 59 : psp_fld_l3_rfs_hfr_PSD_FLUX
# 60 : psp_fld_l3_rfs_hfr_PSD_SFU
# 61 : psp_fld_l3_rfs_hfr_STOKES_V
# 62 : psp_fld_l3_quality_flags
# 63 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2
# 64 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux
# 65 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain
# 66 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum
# 67 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl
# 68 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4
# 69 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux
# 70 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain
# 71 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum
# 72 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl
# 73 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2
# 74 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_flux
# 75 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_gain
# 76 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_nsum
# 77 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_hl
# 78 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4
# 79 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_flux
# 80 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_gain
# 81 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_nsum
# 82 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_hl
# 83 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2
# 84 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux
# 85 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain
# 86 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum
# 87 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl
# 88 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4
# 89 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux
# 90 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain
# 91 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum
# 92 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl
# 93 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2
# 94 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_flux
# 95 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_gain
# 96 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_nsum
# 97 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_hl
# 98 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4
# 99 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_flux
# 100 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_gain
# 101 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_nsum
# 102 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_hl
# 103 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4
# 104 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux
# 105 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain
# 106 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum
# 107 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl
# 108 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4
# 109 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux
# 110 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain
# 111 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum
# 112 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl
# 113 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4
# 114 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain
# 115 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum
# 116 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl
# 117 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4
# 118 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain
# 119 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum
# 120 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl
# 121 : psp_fld_l3_rfs_lfr_ch0_V1V2_RTN
# 122 : psp_fld_l3_rfs_lfr_ch0_V1V2_J2000
# 123 : psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER
# 124 : psp_fld_l3_rfs_lfr_ch0_V1V2_bias
# 125 : psp_fld_l3_rfs_lfr_ch1_V3V4_RTN
# 126 : psp_fld_l3_rfs_lfr_ch1_V3V4_J2000
# 127 : psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER
# 128 : psp_fld_l3_rfs_lfr_ch1_V3V4_bias
# 129 : psp_fld_l3_rfs_lfr_solar_distance
# 130 : psp_fld_l3_rfs_lfr_position_HAE
# 131 : psp_fld_l3_rfs_lfr_position_HCI
# 132 : psp_fld_l3_rfs_lfr_position_HEE
# 133 : psp_fld_l3_rfs_lfr_position_HEEQ
# 134 : psp_fld_l3_rfs_lfr_position_HG
# 135 : psp_fld_l3_rfs_lfr_position_IAU_JUPITER
# 136 : psp_fld_l3_rfs_lfr_position_RTN
# 137 : psp_fld_l3_rfs_lfr_temperature_PA1
# 138 : psp_fld_l3_rfs_lfr_temperature_PA2
# 139 : psp_fld_l3_rfs_lfr_temperature_PA3
# 140 : psp_fld_l3_rfs_lfr_temperature_PA4
# 141 : psp_fld_l3_rfs_lfr_temperature_DCB
# 142 : psp_fld_l3_rfs_lfr_PSD_FLUX
# 143 : psp_fld_l3_rfs_lfr_PSD_SFU
# 144 : psp_fld_l3_rfs_lfr_STOKES_V
# 145 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1
# 146 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_gain
# 147 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_nsum
# 148 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_hl
# 149 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V3
# 150 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_gain
# 151 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_nsum
# 152 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_hl
# 153 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V2
# 154 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_gain
# 155 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_nsum
# 156 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_hl
# 157 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V4
# 158 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_gain
# 159 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_nsum
# 160 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_hl
# 161 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1
# 162 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_gain
# 163 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_nsum
# 164 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_hl
# 165 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3
# 166 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_gain
# 167 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_nsum
# 168 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_hl
# 169 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2
# 170 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_gain
# 171 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_nsum
# 172 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_hl
# 173 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4
# 174 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_gain
# 175 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_nsum
# 176 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_hl
# 177 : psp_fld_l3_rfs_hfr_cross_im_V1_V2
# 178 : psp_fld_l3_rfs_hfr_cross_im_V1_V2_gain
# 179 : psp_fld_l3_rfs_hfr_cross_im_V1_V2_nsum
# 180 : psp_fld_l3_rfs_hfr_cross_im_V1_V2_hl
# 181 : psp_fld_l3_rfs_hfr_cross_im_V3_V4
# 182 : psp_fld_l3_rfs_hfr_cross_im_V3_V4_gain
# 183 : psp_fld_l3_rfs_hfr_cross_im_V3_V4_nsum
# 184 : psp_fld_l3_rfs_hfr_cross_im_V3_V4_hl
# 185 : psp_fld_l3_rfs_hfr_cross_re_V1_V2
# 186 : psp_fld_l3_rfs_hfr_cross_re_V1_V2_gain
# 187 : psp_fld_l3_rfs_hfr_cross_re_V1_V2_nsum
# 188 : psp_fld_l3_rfs_hfr_cross_re_V1_V2_hl
# 189 : psp_fld_l3_rfs_hfr_cross_re_V3_V4
# 190 : psp_fld_l3_rfs_hfr_cross_re_V3_V4_gain
# 191 : psp_fld_l3_rfs_hfr_cross_re_V3_V4_nsum
# 192 : psp_fld_l3_rfs_hfr_cross_re_V3_V4_hl
# 193 : psp_fld_l3_rfs_hfr_coher_V1_V2
# 194 : psp_fld_l3_rfs_hfr_coher_V1_V2_gain
# 195 : psp_fld_l3_rfs_hfr_coher_V1_V2_nsum
# 196 : psp_fld_l3_rfs_hfr_coher_V1_V2_hl
# 197 : psp_fld_l3_rfs_hfr_coher_V3_V4
# 198 : psp_fld_l3_rfs_hfr_coher_V3_V4_gain
# 199 : psp_fld_l3_rfs_hfr_coher_V3_V4_nsum
# 200 : psp_fld_l3_rfs_hfr_coher_V3_V4_hl
# 201 : psp_fld_l3_rfs_hfr_phase_V1_V2
# 202 : psp_fld_l3_rfs_hfr_phase_V1_V2_gain
# 203 : psp_fld_l3_rfs_hfr_phase_V1_V2_nsum
# 204 : psp_fld_l3_rfs_hfr_phase_V1_V2_hl
# 205 : psp_fld_l3_rfs_hfr_phase_V3_V4
# 206 : psp_fld_l3_rfs_hfr_phase_V3_V4_gain
# 207 : psp_fld_l3_rfs_hfr_phase_V3_V4_nsum
# 208 : psp_fld_l3_rfs_hfr_phase_V3_V4_hl
# 209 : psp_fld_l3_rfs_hfr_ch0_V1_RTN
# 210 : psp_fld_l3_rfs_hfr_ch0_V1_J2000
# 211 : psp_fld_l3_rfs_hfr_ch0_V1_IAU_JUPITER
# 212 : psp_fld_l3_rfs_hfr_ch0_V1_bias
# 213 : psp_fld_l3_rfs_hfr_ch0_V3_RTN
# 214 : psp_fld_l3_rfs_hfr_ch0_V3_J2000
# 215 : psp_fld_l3_rfs_hfr_ch0_V3_IAU_JUPITER
# 216 : psp_fld_l3_rfs_hfr_ch0_V3_bias
# 217 : psp_fld_l3_rfs_hfr_ch1_V2_RTN
# 218 : psp_fld_l3_rfs_hfr_ch1_V2_J2000
# 219 : psp_fld_l3_rfs_hfr_ch1_V2_IAU_JUPITER
# 220 : psp_fld_l3_rfs_hfr_ch1_V2_bias
# 221 : psp_fld_l3_rfs_hfr_ch1_V4_RTN
# 222 : psp_fld_l3_rfs_hfr_ch1_V4_J2000
# 223 : psp_fld_l3_rfs_hfr_ch1_V4_IAU_JUPITER
# 224 : psp_fld_l3_rfs_hfr_ch1_V4_bias
# 225 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1
# 226 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_gain
# 227 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_nsum
# 228 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_hl
# 229 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V3
# 230 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_gain
# 231 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_nsum
# 232 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_hl
# 233 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V2
# 234 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_gain
# 235 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_nsum
# 236 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_hl
# 237 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V4
# 238 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_gain
# 239 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_nsum
# 240 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_hl
# 241 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1
# 242 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_gain
# 243 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_nsum
# 244 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_hl
# 245 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3
# 246 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_gain
# 247 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_nsum
# 248 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_hl
# 249 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2
# 250 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_gain
# 251 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_nsum
# 252 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_hl
# 253 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4
# 254 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_gain
# 255 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_nsum
# 256 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_hl
# 257 : psp_fld_l3_rfs_lfr_cross_im_V1_V2
# 258 : psp_fld_l3_rfs_lfr_cross_im_V1_V2_gain
# 259 : psp_fld_l3_rfs_lfr_cross_im_V1_V2_nsum
# 260 : psp_fld_l3_rfs_lfr_cross_im_V1_V2_hl
# 261 : psp_fld_l3_rfs_lfr_cross_im_V3_V4
# 262 : psp_fld_l3_rfs_lfr_cross_im_V3_V4_gain
# 263 : psp_fld_l3_rfs_lfr_cross_im_V3_V4_nsum
# 264 : psp_fld_l3_rfs_lfr_cross_im_V3_V4_hl
# 265 : psp_fld_l3_rfs_lfr_cross_re_V1_V2
# 266 : psp_fld_l3_rfs_lfr_cross_re_V1_V2_gain
# 267 : psp_fld_l3_rfs_lfr_cross_re_V1_V2_nsum
# 268 : psp_fld_l3_rfs_lfr_cross_re_V1_V2_hl
# 269 : psp_fld_l3_rfs_lfr_cross_re_V3_V4
# 270 : psp_fld_l3_rfs_lfr_cross_re_V3_V4_gain
# 271 : psp_fld_l3_rfs_lfr_cross_re_V3_V4_nsum
# 272 : psp_fld_l3_rfs_lfr_cross_re_V3_V4_hl
# 273 : psp_fld_l3_rfs_lfr_coher_V1_V2
# 274 : psp_fld_l3_rfs_lfr_coher_V1_V2_gain
# 275 : psp_fld_l3_rfs_lfr_coher_V1_V2_nsum
# 276 : psp_fld_l3_rfs_lfr_coher_V1_V2_hl
# 277 : psp_fld_l3_rfs_lfr_coher_V3_V4
# 278 : psp_fld_l3_rfs_lfr_coher_V3_V4_gain
# 279 : psp_fld_l3_rfs_lfr_coher_V3_V4_nsum
# 280 : psp_fld_l3_rfs_lfr_coher_V3_V4_hl
# 281 : psp_fld_l3_rfs_lfr_phase_V1_V2
# 282 : psp_fld_l3_rfs_lfr_phase_V1_V2_gain
# 283 : psp_fld_l3_rfs_lfr_phase_V1_V2_nsum
# 284 : psp_fld_l3_rfs_lfr_phase_V1_V2_hl
# 285 : psp_fld_l3_rfs_lfr_phase_V3_V4
# 286 : psp_fld_l3_rfs_lfr_phase_V3_V4_gain
# 287 : psp_fld_l3_rfs_lfr_phase_V3_V4_nsum
# 288 : psp_fld_l3_rfs_lfr_phase_V3_V4_hl
# 289 : psp_fld_l3_rfs_lfr_ch0_V1_RTN
# 290 : psp_fld_l3_rfs_lfr_ch0_V1_J2000
# 291 : psp_fld_l3_rfs_lfr_ch0_V1_IAU_JUPITER
# 292 : psp_fld_l3_rfs_lfr_ch0_V1_bias
# 293 : psp_fld_l3_rfs_lfr_ch0_V3_RTN
# 294 : psp_fld_l3_rfs_lfr_ch0_V3_J2000
# 295 : psp_fld_l3_rfs_lfr_ch0_V3_IAU_JUPITER
# 296 : psp_fld_l3_rfs_lfr_ch0_V3_bias
# 297 : psp_fld_l3_rfs_lfr_ch1_V2_RTN
# 298 : psp_fld_l3_rfs_lfr_ch1_V2_J2000
# 299 : psp_fld_l3_rfs_lfr_ch1_V2_IAU_JUPITER
# 300 : psp_fld_l3_rfs_lfr_ch1_V2_bias
# 301 : psp_fld_l3_rfs_lfr_ch1_V4_RTN
# 302 : psp_fld_l3_rfs_lfr_ch1_V4_J2000
# 303 : psp_fld_l3_rfs_lfr_ch1_V4_IAU_JUPITER
# 304 : psp_fld_l3_rfs_lfr_ch1_V4_bias
# ['psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_hfr_solar_distance',
#  'psp_fld_l3_rfs_hfr_position_HAE',
#  'psp_fld_l3_rfs_hfr_position_HCI',
#  'psp_fld_l3_rfs_hfr_position_HEE',
#  'psp_fld_l3_rfs_hfr_position_HEEQ',
#  'psp_fld_l3_rfs_hfr_position_HG',
#  'psp_fld_l3_rfs_hfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_position_RTN',
#  'psp_fld_l3_rfs_hfr_temperature_PA1',
#  'psp_fld_l3_rfs_hfr_temperature_PA2',
#  'psp_fld_l3_rfs_hfr_temperature_PA3',
#  'psp_fld_l3_rfs_hfr_temperature_PA4',
#  'psp_fld_l3_rfs_hfr_temperature_DCB',
#  'psp_fld_l3_rfs_hfr_PSD_FLUX',
#  'psp_fld_l3_rfs_hfr_PSD_SFU',
#  'psp_fld_l3_rfs_hfr_STOKES_V',
#  'psp_fld_l3_quality_flags',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_lfr_solar_distance',
#  'psp_fld_l3_rfs_lfr_position_HAE',
#  'psp_fld_l3_rfs_lfr_position_HCI',
#  'psp_fld_l3_rfs_lfr_position_HEE',
#  'psp_fld_l3_rfs_lfr_position_HEEQ',
#  'psp_fld_l3_rfs_lfr_position_HG',
#  'psp_fld_l3_rfs_lfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_position_RTN',
#  'psp_fld_l3_rfs_lfr_temperature_PA1',
#  'psp_fld_l3_rfs_lfr_temperature_PA2',
#  'psp_fld_l3_rfs_lfr_temperature_PA3',
#  'psp_fld_l3_rfs_lfr_temperature_PA4',
#  'psp_fld_l3_rfs_lfr_temperature_DCB',
#  'psp_fld_l3_rfs_lfr_PSD_FLUX',
#  'psp_fld_l3_rfs_lfr_PSD_SFU',
#  'psp_fld_l3_rfs_lfr_STOKES_V',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V3',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V2',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V4',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_im_V1_V2',
#  'psp_fld_l3_rfs_hfr_cross_im_V1_V2_gain',
#  'psp_fld_l3_rfs_hfr_cross_im_V1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_cross_im_V1_V2_hl',
#  'psp_fld_l3_rfs_hfr_cross_im_V3_V4',
#  'psp_fld_l3_rfs_hfr_cross_im_V3_V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_im_V3_V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_im_V3_V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_re_V1_V2',
#  'psp_fld_l3_rfs_hfr_cross_re_V1_V2_gain',
#  'psp_fld_l3_rfs_hfr_cross_re_V1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_cross_re_V1_V2_hl',
#  'psp_fld_l3_rfs_hfr_cross_re_V3_V4',
#  'psp_fld_l3_rfs_hfr_cross_re_V3_V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_re_V3_V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_re_V3_V4_hl',
#  'psp_fld_l3_rfs_hfr_coher_V1_V2',
#  'psp_fld_l3_rfs_hfr_coher_V1_V2_gain',
#  'psp_fld_l3_rfs_hfr_coher_V1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_coher_V1_V2_hl',
#  'psp_fld_l3_rfs_hfr_coher_V3_V4',
#  'psp_fld_l3_rfs_hfr_coher_V3_V4_gain',
#  'psp_fld_l3_rfs_hfr_coher_V3_V4_nsum',
#  'psp_fld_l3_rfs_hfr_coher_V3_V4_hl',
#  'psp_fld_l3_rfs_hfr_phase_V1_V2',
#  'psp_fld_l3_rfs_hfr_phase_V1_V2_gain',
#  'psp_fld_l3_rfs_hfr_phase_V1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_phase_V1_V2_hl',
#  'psp_fld_l3_rfs_hfr_phase_V3_V4',
#  'psp_fld_l3_rfs_hfr_phase_V3_V4_gain',
#  'psp_fld_l3_rfs_hfr_phase_V3_V4_nsum',
#  'psp_fld_l3_rfs_hfr_phase_V3_V4_hl',
#  'psp_fld_l3_rfs_hfr_ch0_V1_RTN',
#  'psp_fld_l3_rfs_hfr_ch0_V1_J2000',
#  'psp_fld_l3_rfs_hfr_ch0_V1_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch0_V1_bias',
#  'psp_fld_l3_rfs_hfr_ch0_V3_RTN',
#  'psp_fld_l3_rfs_hfr_ch0_V3_J2000',
#  'psp_fld_l3_rfs_hfr_ch0_V3_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch0_V3_bias',
#  'psp_fld_l3_rfs_hfr_ch1_V2_RTN',
#  'psp_fld_l3_rfs_hfr_ch1_V2_J2000',
#  'psp_fld_l3_rfs_hfr_ch1_V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch1_V2_bias',
#  'psp_fld_l3_rfs_hfr_ch1_V4_RTN',
#  'psp_fld_l3_rfs_hfr_ch1_V4_J2000',
#  'psp_fld_l3_rfs_hfr_ch1_V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch1_V4_bias',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V3',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V2',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V4',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V1_V2',
#  'psp_fld_l3_rfs_lfr_cross_im_V1_V2_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V1_V2_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V3_V4',
#  'psp_fld_l3_rfs_lfr_cross_im_V3_V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V3_V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V3_V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V1_V2',
#  'psp_fld_l3_rfs_lfr_cross_re_V1_V2_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V1_V2_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V3_V4',
#  'psp_fld_l3_rfs_lfr_cross_re_V3_V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V3_V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V3_V4_hl',
#  'psp_fld_l3_rfs_lfr_coher_V1_V2',
#  'psp_fld_l3_rfs_lfr_coher_V1_V2_gain',
#  'psp_fld_l3_rfs_lfr_coher_V1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V1_V2_hl',
#  'psp_fld_l3_rfs_lfr_coher_V3_V4',
#  'psp_fld_l3_rfs_lfr_coher_V3_V4_gain',
#  'psp_fld_l3_rfs_lfr_coher_V3_V4_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V3_V4_hl',
#  'psp_fld_l3_rfs_lfr_phase_V1_V2',
#  'psp_fld_l3_rfs_lfr_phase_V1_V2_gain',
#  'psp_fld_l3_rfs_lfr_phase_V1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V1_V2_hl',
#  'psp_fld_l3_rfs_lfr_phase_V3_V4',
#  'psp_fld_l3_rfs_lfr_phase_V3_V4_gain',
#  'psp_fld_l3_rfs_lfr_phase_V3_V4_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V3_V4_hl',
#  'psp_fld_l3_rfs_lfr_ch0_V1_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V1_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V1_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V1_bias',
#  'psp_fld_l3_rfs_lfr_ch0_V3_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V3_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V3_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V3_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V2_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V2_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V2_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V4_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V4_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V4_bias']

# %%
# get the data

dat = get_data('psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2')

print(dat)
# Out:
# variable(times=array([1.69581600e+09, 1.69581601e+09, 1.69581601e+09, ...,
#        1.69590239e+09, 1.69590240e+09, 1.69590240e+09]), y=array([[9.8911076e-16, 1.2750622e-15, 7.4180022e-16, ..., 5.1455988e-17,
#         5.4947768e-17, 5.9993663e-17],
#        [9.0587484e-16, 1.0500373e-15, 7.8119948e-16, ..., 1.6253829e-16,
#         5.3393920e-17, 6.6001244e-17],
#        [8.3707290e-16, 9.7118246e-16, 8.3933739e-16, ..., 1.4579484e-16,
#         5.5659944e-17, 6.7472487e-17],
#        ...,
#        [5.0653486e-16, 4.3674835e-16, 3.1465453e-16, ..., 2.9087793e-17,
#         2.9762501e-17, 5.5539077e-17],
#        [4.8103483e-16, 4.2136205e-16, 4.6912846e-16, ..., 3.3195168e-17,
#         3.4165067e-17, 4.5444711e-17],
#        [4.5914331e-16, 4.2256409e-16, 4.3693639e-16, ..., 3.5026480e-17,
#         4.2970200e-17, 4.4136945e-17]], dtype=float32), v=array([[ 1275000.,  1321875.,  1378125., ..., 17625000., 18375000.,
#         19171876.],
#        [ 1275000.,  1321875.,  1378125., ..., 17625000., 18375000.,
#         19171876.],
#        [ 1275000.,  1321875.,  1378125., ..., 17625000., 18375000.,
#         19171876.],
#        ...,
#        [ 1275000.,  1321875.,  1378125., ..., 17625000., 18375000.,
#         19171876.],
#        [ 1275000.,  1321875.,  1378125., ..., 17625000., 18375000.,
#         19171876.],
#        [ 1275000.,  1321875.,  1378125., ..., 17625000., 18375000.,
#         19171876.]], dtype=float32))

# %%
trange = ['2022-12-05/12:00', '2022-12-08/20:00']
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_hfr', level='l3')
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_lfr', level='l3')
# Out:
# 09-Jul-24 17:02:16: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2022/
# 09-Jul-24 17:02:17: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221205_v03.cdf to psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221205_v03.cdf
# 09-Jul-24 17:02:18: Download complete: psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221205_v03.cdf
# 09-Jul-24 17:02:19: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221206_v03.cdf to psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221206_v03.cdf
# 09-Jul-24 17:02:29: Download complete: psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221206_v03.cdf
# 09-Jul-24 17:02:29: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221207_v03.cdf to psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221207_v03.cdf
# 09-Jul-24 17:02:45: Download complete: psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221207_v03.cdf
# 09-Jul-24 17:02:46: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221208_v03.cdf to psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221208_v03.cdf
# 09-Jul-24 17:03:17: Download complete: psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221208_v03.cdf
# 09-Jul-24 17:03:24: psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 09-Jul-24 17:03:24: psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_flux contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 09-Jul-24 17:03:24: psp_fld_l3_rfs_hfr_coher_V1V2_V3V4 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 09-Jul-24 17:03:25: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2022/
# 09-Jul-24 17:03:26: File is current: psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221205_v03.cdf
# 09-Jul-24 17:03:26: File is current: psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221206_v03.cdf
# 09-Jul-24 17:03:26: File is current: psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221207_v03.cdf
# 09-Jul-24 17:03:26: File is current: psp_data/fields/l3/rfs_hfr/2022/psp_fld_l3_rfs_hfr_20221208_v03.cdf
# 09-Jul-24 17:03:27: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2022/
# 09-Jul-24 17:03:27: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221205_v03.cdf to psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221205_v03.cdf
# 09-Jul-24 17:03:31: Download complete: psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221205_v03.cdf
# 09-Jul-24 17:03:32: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221206_v03.cdf to psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221206_v03.cdf
# 09-Jul-24 17:04:13: Download complete: psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221206_v03.cdf
# 09-Jul-24 17:04:13: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221207_v03.cdf to psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221207_v03.cdf
# 09-Jul-24 17:05:03: Download complete: psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221207_v03.cdf
# 09-Jul-24 17:05:04: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221208_v03.cdf to psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221208_v03.cdf
# 09-Jul-24 17:05:49: Download complete: psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221208_v03.cdf
# 09-Jul-24 17:06:01: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2022/
# 09-Jul-24 17:06:01: File is current: psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221205_v03.cdf
# 09-Jul-24 17:06:02: File is current: psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221206_v03.cdf
# 09-Jul-24 17:06:02: File is current: psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221207_v03.cdf
# 09-Jul-24 17:06:02: File is current: psp_data/fields/l3/rfs_lfr/2022/psp_fld_l3_rfs_lfr_20221208_v03.cdf
# ['psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_lfr_solar_distance',
#  'psp_fld_l3_rfs_lfr_position_HAE',
#  'psp_fld_l3_rfs_lfr_position_HCI',
#  'psp_fld_l3_rfs_lfr_position_HEE',
#  'psp_fld_l3_rfs_lfr_position_HEEQ',
#  'psp_fld_l3_rfs_lfr_position_HG',
#  'psp_fld_l3_rfs_lfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_position_RTN',
#  'psp_fld_l3_rfs_lfr_temperature_PA1',
#  'psp_fld_l3_rfs_lfr_temperature_PA2',
#  'psp_fld_l3_rfs_lfr_temperature_PA3',
#  'psp_fld_l3_rfs_lfr_temperature_PA4',
#  'psp_fld_l3_rfs_lfr_temperature_DCB',
#  'psp_fld_l3_rfs_lfr_PSD_FLUX',
#  'psp_fld_l3_rfs_lfr_PSD_SFU',
#  'psp_fld_l3_rfs_lfr_STOKES_V',
#  'psp_fld_l3_quality_flags']

# %%
trange = ['2023-10-31/12:00', '2023-10-31/20:00']
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_hfr', level='l3')
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_lfr', level='l3')
# Out:
# 09-Jul-24 17:06:02: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 09-Jul-24 17:06:03: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20231031_v03.cdf to psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20231031_v03.cdf
# 09-Jul-24 17:06:06: Download complete: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20231031_v03.cdf
# 09-Jul-24 17:06:08: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 09-Jul-24 17:06:09: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20231031_v03.cdf
# 09-Jul-24 17:06:09: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 09-Jul-24 17:06:09: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20231031_v03.cdf to psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20231031_v03.cdf
# 09-Jul-24 17:06:19: Download complete: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20231031_v03.cdf
# 09-Jul-24 17:06:21: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 09-Jul-24 17:06:22: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20231031_v03.cdf
# ['psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_lfr_solar_distance',
#  'psp_fld_l3_rfs_lfr_position_HAE',
#  'psp_fld_l3_rfs_lfr_position_HCI',
#  'psp_fld_l3_rfs_lfr_position_HEE',
#  'psp_fld_l3_rfs_lfr_position_HEEQ',
#  'psp_fld_l3_rfs_lfr_position_HG',
#  'psp_fld_l3_rfs_lfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_position_RTN',
#  'psp_fld_l3_rfs_lfr_temperature_PA1',
#  'psp_fld_l3_rfs_lfr_temperature_PA2',
#  'psp_fld_l3_rfs_lfr_temperature_PA3',
#  'psp_fld_l3_rfs_lfr_temperature_PA4',
#  'psp_fld_l3_rfs_lfr_temperature_DCB',
#  'psp_fld_l3_rfs_lfr_PSD_FLUX',
#  'psp_fld_l3_rfs_lfr_PSD_SFU',
#  'psp_fld_l3_rfs_lfr_STOKES_V',
#  'psp_fld_l3_quality_flags']

# %%
tplot_names()
# Out:
# 0 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2
# 1 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_flux
# 2 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_gain
# 3 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_nsum
# 4 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_hl
# 5 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4
# 6 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_flux
# 7 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_gain
# 8 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_nsum
# 9 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_hl
# 10 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2
# 11 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_flux
# 12 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_gain
# 13 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_nsum
# 14 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_hl
# 15 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4
# 16 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_flux
# 17 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_gain
# 18 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_nsum
# 19 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_hl
# 20 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4
# 21 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_flux
# 22 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_gain
# 23 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_nsum
# 24 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_hl
# 25 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4
# 26 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_flux
# 27 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_gain
# 28 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_nsum
# 29 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_hl
# 30 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4
# 31 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_gain
# 32 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_nsum
# 33 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_hl
# 34 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4
# 35 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_gain
# 36 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_nsum
# 37 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_hl
# 38 : psp_fld_l3_rfs_hfr_ch0_V1V2_RTN
# 39 : psp_fld_l3_rfs_hfr_ch0_V1V2_J2000
# 40 : psp_fld_l3_rfs_hfr_ch0_V1V2_IAU_JUPITER
# 41 : psp_fld_l3_rfs_hfr_ch0_V1V2_bias
# 42 : psp_fld_l3_rfs_hfr_ch1_V3V4_RTN
# 43 : psp_fld_l3_rfs_hfr_ch1_V3V4_J2000
# 44 : psp_fld_l3_rfs_hfr_ch1_V3V4_IAU_JUPITER
# 45 : psp_fld_l3_rfs_hfr_ch1_V3V4_bias
# 46 : psp_fld_l3_rfs_hfr_solar_distance
# 47 : psp_fld_l3_rfs_hfr_position_HAE
# 48 : psp_fld_l3_rfs_hfr_position_HCI
# 49 : psp_fld_l3_rfs_hfr_position_HEE
# 50 : psp_fld_l3_rfs_hfr_position_HEEQ
# 51 : psp_fld_l3_rfs_hfr_position_HG
# 52 : psp_fld_l3_rfs_hfr_position_IAU_JUPITER
# 53 : psp_fld_l3_rfs_hfr_position_RTN
# 54 : psp_fld_l3_rfs_hfr_temperature_PA1
# 55 : psp_fld_l3_rfs_hfr_temperature_PA2
# 56 : psp_fld_l3_rfs_hfr_temperature_PA3
# 57 : psp_fld_l3_rfs_hfr_temperature_PA4
# 58 : psp_fld_l3_rfs_hfr_temperature_DCB
# 59 : psp_fld_l3_rfs_hfr_PSD_FLUX
# 60 : psp_fld_l3_rfs_hfr_PSD_SFU
# 61 : psp_fld_l3_rfs_hfr_STOKES_V
# 62 : psp_fld_l3_quality_flags
# 63 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2
# 64 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux
# 65 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain
# 66 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum
# 67 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl
# 68 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4
# 69 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux
# 70 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain
# 71 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum
# 72 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl
# 73 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2
# 74 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_flux
# 75 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_gain
# 76 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_nsum
# 77 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_hl
# 78 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4
# 79 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_flux
# 80 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_gain
# 81 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_nsum
# 82 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_hl
# 83 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2
# 84 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux
# 85 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain
# 86 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum
# 87 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl
# 88 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4
# 89 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux
# 90 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain
# 91 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum
# 92 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl
# 93 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2
# 94 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_flux
# 95 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_gain
# 96 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_nsum
# 97 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_hl
# 98 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4
# 99 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_flux
# 100 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_gain
# 101 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_nsum
# 102 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_hl
# 103 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4
# 104 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux
# 105 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain
# 106 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum
# 107 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl
# 108 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4
# 109 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux
# 110 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain
# 111 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum
# 112 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl
# 113 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4
# 114 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain
# 115 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum
# 116 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl
# 117 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4
# 118 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain
# 119 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum
# 120 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl
# 121 : psp_fld_l3_rfs_lfr_ch0_V1V2_RTN
# 122 : psp_fld_l3_rfs_lfr_ch0_V1V2_J2000
# 123 : psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER
# 124 : psp_fld_l3_rfs_lfr_ch0_V1V2_bias
# 125 : psp_fld_l3_rfs_lfr_ch1_V3V4_RTN
# 126 : psp_fld_l3_rfs_lfr_ch1_V3V4_J2000
# 127 : psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER
# 128 : psp_fld_l3_rfs_lfr_ch1_V3V4_bias
# 129 : psp_fld_l3_rfs_lfr_solar_distance
# 130 : psp_fld_l3_rfs_lfr_position_HAE
# 131 : psp_fld_l3_rfs_lfr_position_HCI
# 132 : psp_fld_l3_rfs_lfr_position_HEE
# 133 : psp_fld_l3_rfs_lfr_position_HEEQ
# 134 : psp_fld_l3_rfs_lfr_position_HG
# 135 : psp_fld_l3_rfs_lfr_position_IAU_JUPITER
# 136 : psp_fld_l3_rfs_lfr_position_RTN
# 137 : psp_fld_l3_rfs_lfr_temperature_PA1
# 138 : psp_fld_l3_rfs_lfr_temperature_PA2
# 139 : psp_fld_l3_rfs_lfr_temperature_PA3
# 140 : psp_fld_l3_rfs_lfr_temperature_PA4
# 141 : psp_fld_l3_rfs_lfr_temperature_DCB
# 142 : psp_fld_l3_rfs_lfr_PSD_FLUX
# 143 : psp_fld_l3_rfs_lfr_PSD_SFU
# 144 : psp_fld_l3_rfs_lfr_STOKES_V
# 145 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1
# 146 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_gain
# 147 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_nsum
# 148 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_hl
# 149 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V3
# 150 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_gain
# 151 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_nsum
# 152 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_hl
# 153 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V2
# 154 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_gain
# 155 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_nsum
# 156 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_hl
# 157 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V4
# 158 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_gain
# 159 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_nsum
# 160 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_hl
# 161 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1
# 162 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_gain
# 163 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_nsum
# 164 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_hl
# 165 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3
# 166 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_gain
# 167 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_nsum
# 168 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_hl
# 169 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2
# 170 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_gain
# 171 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_nsum
# 172 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_hl
# 173 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4
# 174 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_gain
# 175 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_nsum
# 176 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_hl
# 177 : psp_fld_l3_rfs_hfr_cross_im_V1_V2
# 178 : psp_fld_l3_rfs_hfr_cross_im_V1_V2_gain
# 179 : psp_fld_l3_rfs_hfr_cross_im_V1_V2_nsum
# 180 : psp_fld_l3_rfs_hfr_cross_im_V1_V2_hl
# 181 : psp_fld_l3_rfs_hfr_cross_im_V3_V4
# 182 : psp_fld_l3_rfs_hfr_cross_im_V3_V4_gain
# 183 : psp_fld_l3_rfs_hfr_cross_im_V3_V4_nsum
# 184 : psp_fld_l3_rfs_hfr_cross_im_V3_V4_hl
# 185 : psp_fld_l3_rfs_hfr_cross_re_V1_V2
# 186 : psp_fld_l3_rfs_hfr_cross_re_V1_V2_gain
# 187 : psp_fld_l3_rfs_hfr_cross_re_V1_V2_nsum
# 188 : psp_fld_l3_rfs_hfr_cross_re_V1_V2_hl
# 189 : psp_fld_l3_rfs_hfr_cross_re_V3_V4
# 190 : psp_fld_l3_rfs_hfr_cross_re_V3_V4_gain
# 191 : psp_fld_l3_rfs_hfr_cross_re_V3_V4_nsum
# 192 : psp_fld_l3_rfs_hfr_cross_re_V3_V4_hl
# 193 : psp_fld_l3_rfs_hfr_coher_V1_V2
# 194 : psp_fld_l3_rfs_hfr_coher_V1_V2_gain
# 195 : psp_fld_l3_rfs_hfr_coher_V1_V2_nsum
# 196 : psp_fld_l3_rfs_hfr_coher_V1_V2_hl
# 197 : psp_fld_l3_rfs_hfr_coher_V3_V4
# 198 : psp_fld_l3_rfs_hfr_coher_V3_V4_gain
# 199 : psp_fld_l3_rfs_hfr_coher_V3_V4_nsum
# 200 : psp_fld_l3_rfs_hfr_coher_V3_V4_hl
# 201 : psp_fld_l3_rfs_hfr_phase_V1_V2
# 202 : psp_fld_l3_rfs_hfr_phase_V1_V2_gain
# 203 : psp_fld_l3_rfs_hfr_phase_V1_V2_nsum
# 204 : psp_fld_l3_rfs_hfr_phase_V1_V2_hl
# 205 : psp_fld_l3_rfs_hfr_phase_V3_V4
# 206 : psp_fld_l3_rfs_hfr_phase_V3_V4_gain
# 207 : psp_fld_l3_rfs_hfr_phase_V3_V4_nsum
# 208 : psp_fld_l3_rfs_hfr_phase_V3_V4_hl
# 209 : psp_fld_l3_rfs_hfr_ch0_V1_RTN
# 210 : psp_fld_l3_rfs_hfr_ch0_V1_J2000
# 211 : psp_fld_l3_rfs_hfr_ch0_V1_IAU_JUPITER
# 212 : psp_fld_l3_rfs_hfr_ch0_V1_bias
# 213 : psp_fld_l3_rfs_hfr_ch0_V3_RTN
# 214 : psp_fld_l3_rfs_hfr_ch0_V3_J2000
# 215 : psp_fld_l3_rfs_hfr_ch0_V3_IAU_JUPITER
# 216 : psp_fld_l3_rfs_hfr_ch0_V3_bias
# 217 : psp_fld_l3_rfs_hfr_ch1_V2_RTN
# 218 : psp_fld_l3_rfs_hfr_ch1_V2_J2000
# 219 : psp_fld_l3_rfs_hfr_ch1_V2_IAU_JUPITER
# 220 : psp_fld_l3_rfs_hfr_ch1_V2_bias
# 221 : psp_fld_l3_rfs_hfr_ch1_V4_RTN
# 222 : psp_fld_l3_rfs_hfr_ch1_V4_J2000
# 223 : psp_fld_l3_rfs_hfr_ch1_V4_IAU_JUPITER
# 224 : psp_fld_l3_rfs_hfr_ch1_V4_bias
# 225 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1
# 226 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_gain
# 227 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_nsum
# 228 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_hl
# 229 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V3
# 230 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_gain
# 231 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_nsum
# 232 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_hl
# 233 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V2
# 234 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_gain
# 235 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_nsum
# 236 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_hl
# 237 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V4
# 238 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_gain
# 239 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_nsum
# 240 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_hl
# 241 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1
# 242 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_gain
# 243 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_nsum
# 244 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_hl
# 245 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3
# 246 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_gain
# 247 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_nsum
# 248 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_hl
# 249 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2
# 250 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_gain
# 251 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_nsum
# 252 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_hl
# 253 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4
# 254 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_gain
# 255 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_nsum
# 256 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_hl
# 257 : psp_fld_l3_rfs_lfr_cross_im_V1_V2
# 258 : psp_fld_l3_rfs_lfr_cross_im_V1_V2_gain
# 259 : psp_fld_l3_rfs_lfr_cross_im_V1_V2_nsum
# 260 : psp_fld_l3_rfs_lfr_cross_im_V1_V2_hl
# 261 : psp_fld_l3_rfs_lfr_cross_im_V3_V4
# 262 : psp_fld_l3_rfs_lfr_cross_im_V3_V4_gain
# 263 : psp_fld_l3_rfs_lfr_cross_im_V3_V4_nsum
# 264 : psp_fld_l3_rfs_lfr_cross_im_V3_V4_hl
# 265 : psp_fld_l3_rfs_lfr_cross_re_V1_V2
# 266 : psp_fld_l3_rfs_lfr_cross_re_V1_V2_gain
# 267 : psp_fld_l3_rfs_lfr_cross_re_V1_V2_nsum
# 268 : psp_fld_l3_rfs_lfr_cross_re_V1_V2_hl
# 269 : psp_fld_l3_rfs_lfr_cross_re_V3_V4
# 270 : psp_fld_l3_rfs_lfr_cross_re_V3_V4_gain
# 271 : psp_fld_l3_rfs_lfr_cross_re_V3_V4_nsum
# 272 : psp_fld_l3_rfs_lfr_cross_re_V3_V4_hl
# 273 : psp_fld_l3_rfs_lfr_coher_V1_V2
# 274 : psp_fld_l3_rfs_lfr_coher_V1_V2_gain
# 275 : psp_fld_l3_rfs_lfr_coher_V1_V2_nsum
# 276 : psp_fld_l3_rfs_lfr_coher_V1_V2_hl
# 277 : psp_fld_l3_rfs_lfr_coher_V3_V4
# 278 : psp_fld_l3_rfs_lfr_coher_V3_V4_gain
# 279 : psp_fld_l3_rfs_lfr_coher_V3_V4_nsum
# 280 : psp_fld_l3_rfs_lfr_coher_V3_V4_hl
# 281 : psp_fld_l3_rfs_lfr_phase_V1_V2
# 282 : psp_fld_l3_rfs_lfr_phase_V1_V2_gain
# 283 : psp_fld_l3_rfs_lfr_phase_V1_V2_nsum
# 284 : psp_fld_l3_rfs_lfr_phase_V1_V2_hl
# 285 : psp_fld_l3_rfs_lfr_phase_V3_V4
# 286 : psp_fld_l3_rfs_lfr_phase_V3_V4_gain
# 287 : psp_fld_l3_rfs_lfr_phase_V3_V4_nsum
# 288 : psp_fld_l3_rfs_lfr_phase_V3_V4_hl
# 289 : psp_fld_l3_rfs_lfr_ch0_V1_RTN
# 290 : psp_fld_l3_rfs_lfr_ch0_V1_J2000
# 291 : psp_fld_l3_rfs_lfr_ch0_V1_IAU_JUPITER
# 292 : psp_fld_l3_rfs_lfr_ch0_V1_bias
# 293 : psp_fld_l3_rfs_lfr_ch0_V3_RTN
# 294 : psp_fld_l3_rfs_lfr_ch0_V3_J2000
# 295 : psp_fld_l3_rfs_lfr_ch0_V3_IAU_JUPITER
# 296 : psp_fld_l3_rfs_lfr_ch0_V3_bias
# 297 : psp_fld_l3_rfs_lfr_ch1_V2_RTN
# 298 : psp_fld_l3_rfs_lfr_ch1_V2_J2000
# 299 : psp_fld_l3_rfs_lfr_ch1_V2_IAU_JUPITER
# 300 : psp_fld_l3_rfs_lfr_ch1_V2_bias
# 301 : psp_fld_l3_rfs_lfr_ch1_V4_RTN
# 302 : psp_fld_l3_rfs_lfr_ch1_V4_J2000
# 303 : psp_fld_l3_rfs_lfr_ch1_V4_IAU_JUPITER
# 304 : psp_fld_l3_rfs_lfr_ch1_V4_bias
# ['psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_hfr_solar_distance',
#  'psp_fld_l3_rfs_hfr_position_HAE',
#  'psp_fld_l3_rfs_hfr_position_HCI',
#  'psp_fld_l3_rfs_hfr_position_HEE',
#  'psp_fld_l3_rfs_hfr_position_HEEQ',
#  'psp_fld_l3_rfs_hfr_position_HG',
#  'psp_fld_l3_rfs_hfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_position_RTN',
#  'psp_fld_l3_rfs_hfr_temperature_PA1',
#  'psp_fld_l3_rfs_hfr_temperature_PA2',
#  'psp_fld_l3_rfs_hfr_temperature_PA3',
#  'psp_fld_l3_rfs_hfr_temperature_PA4',
#  'psp_fld_l3_rfs_hfr_temperature_DCB',
#  'psp_fld_l3_rfs_hfr_PSD_FLUX',
#  'psp_fld_l3_rfs_hfr_PSD_SFU',
#  'psp_fld_l3_rfs_hfr_STOKES_V',
#  'psp_fld_l3_quality_flags',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_lfr_solar_distance',
#  'psp_fld_l3_rfs_lfr_position_HAE',
#  'psp_fld_l3_rfs_lfr_position_HCI',
#  'psp_fld_l3_rfs_lfr_position_HEE',
#  'psp_fld_l3_rfs_lfr_position_HEEQ',
#  'psp_fld_l3_rfs_lfr_position_HG',
#  'psp_fld_l3_rfs_lfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_position_RTN',
#  'psp_fld_l3_rfs_lfr_temperature_PA1',
#  'psp_fld_l3_rfs_lfr_temperature_PA2',
#  'psp_fld_l3_rfs_lfr_temperature_PA3',
#  'psp_fld_l3_rfs_lfr_temperature_PA4',
#  'psp_fld_l3_rfs_lfr_temperature_DCB',
#  'psp_fld_l3_rfs_lfr_PSD_FLUX',
#  'psp_fld_l3_rfs_lfr_PSD_SFU',
#  'psp_fld_l3_rfs_lfr_STOKES_V',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V3',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V3_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V2',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V4',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V4_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V3_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_im_V1_V2',
#  'psp_fld_l3_rfs_hfr_cross_im_V1_V2_gain',
#  'psp_fld_l3_rfs_hfr_cross_im_V1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_cross_im_V1_V2_hl',
#  'psp_fld_l3_rfs_hfr_cross_im_V3_V4',
#  'psp_fld_l3_rfs_hfr_cross_im_V3_V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_im_V3_V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_im_V3_V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_re_V1_V2',
#  'psp_fld_l3_rfs_hfr_cross_re_V1_V2_gain',
#  'psp_fld_l3_rfs_hfr_cross_re_V1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_cross_re_V1_V2_hl',
#  'psp_fld_l3_rfs_hfr_cross_re_V3_V4',
#  'psp_fld_l3_rfs_hfr_cross_re_V3_V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_re_V3_V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_re_V3_V4_hl',
#  'psp_fld_l3_rfs_hfr_coher_V1_V2',
#  'psp_fld_l3_rfs_hfr_coher_V1_V2_gain',
#  'psp_fld_l3_rfs_hfr_coher_V1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_coher_V1_V2_hl',
#  'psp_fld_l3_rfs_hfr_coher_V3_V4',
#  'psp_fld_l3_rfs_hfr_coher_V3_V4_gain',
#  'psp_fld_l3_rfs_hfr_coher_V3_V4_nsum',
#  'psp_fld_l3_rfs_hfr_coher_V3_V4_hl',
#  'psp_fld_l3_rfs_hfr_phase_V1_V2',
#  'psp_fld_l3_rfs_hfr_phase_V1_V2_gain',
#  'psp_fld_l3_rfs_hfr_phase_V1_V2_nsum',
#  'psp_fld_l3_rfs_hfr_phase_V1_V2_hl',
#  'psp_fld_l3_rfs_hfr_phase_V3_V4',
#  'psp_fld_l3_rfs_hfr_phase_V3_V4_gain',
#  'psp_fld_l3_rfs_hfr_phase_V3_V4_nsum',
#  'psp_fld_l3_rfs_hfr_phase_V3_V4_hl',
#  'psp_fld_l3_rfs_hfr_ch0_V1_RTN',
#  'psp_fld_l3_rfs_hfr_ch0_V1_J2000',
#  'psp_fld_l3_rfs_hfr_ch0_V1_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch0_V1_bias',
#  'psp_fld_l3_rfs_hfr_ch0_V3_RTN',
#  'psp_fld_l3_rfs_hfr_ch0_V3_J2000',
#  'psp_fld_l3_rfs_hfr_ch0_V3_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch0_V3_bias',
#  'psp_fld_l3_rfs_hfr_ch1_V2_RTN',
#  'psp_fld_l3_rfs_hfr_ch1_V2_J2000',
#  'psp_fld_l3_rfs_hfr_ch1_V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch1_V2_bias',
#  'psp_fld_l3_rfs_hfr_ch1_V4_RTN',
#  'psp_fld_l3_rfs_hfr_ch1_V4_J2000',
#  'psp_fld_l3_rfs_hfr_ch1_V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch1_V4_bias',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V3',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V3_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V2',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V4',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V4_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V3_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V1_V2',
#  'psp_fld_l3_rfs_lfr_cross_im_V1_V2_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V1_V2_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V3_V4',
#  'psp_fld_l3_rfs_lfr_cross_im_V3_V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V3_V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V3_V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V1_V2',
#  'psp_fld_l3_rfs_lfr_cross_re_V1_V2_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V1_V2_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V3_V4',
#  'psp_fld_l3_rfs_lfr_cross_re_V3_V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V3_V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V3_V4_hl',
#  'psp_fld_l3_rfs_lfr_coher_V1_V2',
#  'psp_fld_l3_rfs_lfr_coher_V1_V2_gain',
#  'psp_fld_l3_rfs_lfr_coher_V1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V1_V2_hl',
#  'psp_fld_l3_rfs_lfr_coher_V3_V4',
#  'psp_fld_l3_rfs_lfr_coher_V3_V4_gain',
#  'psp_fld_l3_rfs_lfr_coher_V3_V4_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V3_V4_hl',
#  'psp_fld_l3_rfs_lfr_phase_V1_V2',
#  'psp_fld_l3_rfs_lfr_phase_V1_V2_gain',
#  'psp_fld_l3_rfs_lfr_phase_V1_V2_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V1_V2_hl',
#  'psp_fld_l3_rfs_lfr_phase_V3_V4',
#  'psp_fld_l3_rfs_lfr_phase_V3_V4_gain',
#  'psp_fld_l3_rfs_lfr_phase_V3_V4_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V3_V4_hl',
#  'psp_fld_l3_rfs_lfr_ch0_V1_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V1_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V1_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V1_bias',
#  'psp_fld_l3_rfs_lfr_ch0_V3_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V3_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V3_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V3_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V2_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V2_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V2_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V4_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V4_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V4_bias']

# %%
tplot([1, 64])

# %%
tplot(0)

# %%
tplot(1)

# %%
tplot([0, 63, 1, 64])

# %%
tplot(['psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2',
       'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2',
       'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4',
       'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4'
      ])

# %%
tplot(['psp_fld_l3_rfs_hfr_auto_averages_ch0_V1', 
       'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1'
      ])

# %%
tplot(145)

# %%
tplot(144)
