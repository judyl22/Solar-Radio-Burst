# %%
import pyspedas
from pytplot import tplot
from pytplot import tplot_names

# %%
fields_vars = pyspedas.psp.fields(trange=['2018-11-5', '2018-11-5/06:00'], datatype='mag_rtn', level='l2', time_clip=True)
# Out:
# 09-Jul-24 13:20:25: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn/2018/
# 09-Jul-24 13:20:25: File is current: psp_data/fields/l2/mag_rtn/2018/psp_fld_l2_mag_rtn_2018110500_v02.cdf
# 09-Jul-24 13:20:29: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn/2018/
# 09-Jul-24 13:20:30: File is current: psp_data/fields/l2/mag_rtn/2018/psp_fld_l2_mag_rtn_2018110500_v02.cdf

# %%
rfs_hfr = pyspedas.psp.fields(trange=['2018-11-5', '2018-11-5/06:00'], datatype='rfs_hfr', level='l2', time_clip=True)
# Out:
# 09-Jul-24 13:20:30: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/rfs_hfr/2018/
# 09-Jul-24 13:20:30: File is current: psp_data/fields/l2/rfs_hfr/2018/psp_fld_l2_rfs_hfr_20181105_v03.cdf

# %%
rfs_lfr = pyspedas.psp.fields(trange=['2018-11-5', '2018-11-5/06:00'], datatype='rfs_lfr', level='l2', time_clip=True)
# Out:
# 09-Jul-24 13:20:34: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/rfs_lfr/2018/
# 09-Jul-24 13:20:35: File is current: psp_data/fields/l2/rfs_lfr/2018/psp_fld_l2_rfs_lfr_20181105_v03.cdf

# %%
tplot_names()
# Out:
# 0 : psp_fld_l2_mag_RTN
# 1 : psp_fld_l2_quality_flags
# 2 : psp_fld_l2_rfs_hfr_auto_averages_ch0_V1V2
# 3 : psp_fld_l2_rfs_hfr_auto_averages_ch0_V1V2_gain
# 4 : psp_fld_l2_rfs_hfr_auto_averages_ch0_V1V2_nsum
# 5 : psp_fld_l2_rfs_hfr_auto_averages_ch0_V1V2_hl
# 6 : psp_fld_l2_rfs_hfr_auto_averages_ch1_V3V4
# 7 : psp_fld_l2_rfs_hfr_auto_averages_ch1_V3V4_gain
# 8 : psp_fld_l2_rfs_hfr_auto_averages_ch1_V3V4_nsum
# 9 : psp_fld_l2_rfs_hfr_auto_averages_ch1_V3V4_hl
# 10 : psp_fld_l2_rfs_hfr_auto_peaks_ch0_V1V2
# 11 : psp_fld_l2_rfs_hfr_auto_peaks_ch0_V1V2_gain
# 12 : psp_fld_l2_rfs_hfr_auto_peaks_ch0_V1V2_nsum
# 13 : psp_fld_l2_rfs_hfr_auto_peaks_ch0_V1V2_hl
# 14 : psp_fld_l2_rfs_hfr_auto_peaks_ch1_V3V4
# 15 : psp_fld_l2_rfs_hfr_auto_peaks_ch1_V3V4_gain
# 16 : psp_fld_l2_rfs_hfr_auto_peaks_ch1_V3V4_nsum
# 17 : psp_fld_l2_rfs_hfr_auto_peaks_ch1_V3V4_hl
# 18 : psp_fld_l2_rfs_hfr_cross_im_V1V2_V3V4
# 19 : psp_fld_l2_rfs_hfr_cross_im_V1V2_V3V4_gain
# ...

# %%
import numpy as np

# %%
tplot(2)

# %%
tplot(6)

# %%
tplot(10)

# %%
tplot(14)

# %%
tplot(18)

# %%
tplot(22)

# %%
tplot(26)

# %%
tplot(30)

# %%
tplot(41)

# %%
tplot(45)

# %%
tplot(49)

# %%
tplot(53)

# %%
tplot(65)

# %%
tplot(69)

# %%
tplot(73)

# %%
tplot(77)

# %%
tplot(81)

# %%
tplot(85)
