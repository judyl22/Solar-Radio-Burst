# %%
import pyspedas
from pytplot import tplot, tplot_names, options, get_data

# %%
trange = ['2023-10-31/12:00', '2023-10-31/20:00']
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_hfr', level='l3')
pyspedas.psp.fields(trange=trange, time_clip=True, datatype='rfs_lfr', level='l3')
# Out:
# 10-Jul-24 11:19:50: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 10-Jul-24 11:19:50: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20231031_v03.cdf
# 10-Jul-24 11:19:53: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 10-Jul-24 11:19:54: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20231031_v03.cdf
# 10-Jul-24 11:19:54: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 10-Jul-24 11:19:54: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20231031_v03.cdf
# 10-Jul-24 11:19:58: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 10-Jul-24 11:19:58: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20231031_v03.cdf
# ['psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_lfr_solar_distance',
#  'psp_fld_l3_rfs_lfr_position_HAE',
#  'psp_fld_l3_rfs_lfr_position_HCI',
#  'psp_fld_l3_rfs_lfr_position_HEE',
#  'psp_fld_l3_rfs_lfr_position_HEEQ',
#  'psp_fld_l3_rfs_lfr_position_HG',
#  'psp_fld_l3_rfs_lfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_position_RTN',
#  'psp_fld_l3_rfs_lfr_temperature_PA1',
#  'psp_fld_l3_rfs_lfr_temperature_PA2',
#  'psp_fld_l3_rfs_lfr_temperature_PA3',
#  'psp_fld_l3_rfs_lfr_temperature_PA4',
#  'psp_fld_l3_rfs_lfr_temperature_DCB',
#  'psp_fld_l3_rfs_lfr_PSD_FLUX',
#  'psp_fld_l3_rfs_lfr_PSD_SFU',
#  'psp_fld_l3_rfs_lfr_STOKES_V',
#  'psp_fld_l3_quality_flags']

# %%
tplot_names()
# Out:
# 0 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2
# 1 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_flux
# 2 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_gain
# 3 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_nsum
# 4 : psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_hl
# 5 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4
# 6 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_flux
# 7 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_gain
# 8 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_nsum
# 9 : psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_hl
# 10 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2
# 11 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_flux
# 12 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_gain
# 13 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_nsum
# 14 : psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_hl
# 15 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4
# 16 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_flux
# 17 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_gain
# 18 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_nsum
# 19 : psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_hl
# 20 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4
# 21 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_flux
# 22 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_gain
# 23 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_nsum
# 24 : psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_hl
# 25 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4
# 26 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_flux
# 27 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_gain
# 28 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_nsum
# 29 : psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_hl
# 30 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4
# 31 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_gain
# 32 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_nsum
# 33 : psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_hl
# 34 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4
# 35 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_gain
# 36 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_nsum
# 37 : psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_hl
# 38 : psp_fld_l3_rfs_hfr_ch0_V1V2_RTN
# 39 : psp_fld_l3_rfs_hfr_ch0_V1V2_J2000
# 40 : psp_fld_l3_rfs_hfr_ch0_V1V2_IAU_JUPITER
# 41 : psp_fld_l3_rfs_hfr_ch0_V1V2_bias
# 42 : psp_fld_l3_rfs_hfr_ch1_V3V4_RTN
# 43 : psp_fld_l3_rfs_hfr_ch1_V3V4_J2000
# 44 : psp_fld_l3_rfs_hfr_ch1_V3V4_IAU_JUPITER
# 45 : psp_fld_l3_rfs_hfr_ch1_V3V4_bias
# 46 : psp_fld_l3_rfs_hfr_solar_distance
# 47 : psp_fld_l3_rfs_hfr_position_HAE
# 48 : psp_fld_l3_rfs_hfr_position_HCI
# 49 : psp_fld_l3_rfs_hfr_position_HEE
# 50 : psp_fld_l3_rfs_hfr_position_HEEQ
# 51 : psp_fld_l3_rfs_hfr_position_HG
# 52 : psp_fld_l3_rfs_hfr_position_IAU_JUPITER
# 53 : psp_fld_l3_rfs_hfr_position_RTN
# 54 : psp_fld_l3_rfs_hfr_temperature_PA1
# 55 : psp_fld_l3_rfs_hfr_temperature_PA2
# 56 : psp_fld_l3_rfs_hfr_temperature_PA3
# 57 : psp_fld_l3_rfs_hfr_temperature_PA4
# 58 : psp_fld_l3_rfs_hfr_temperature_DCB
# 59 : psp_fld_l3_rfs_hfr_PSD_FLUX
# 60 : psp_fld_l3_rfs_hfr_PSD_SFU
# 61 : psp_fld_l3_rfs_hfr_STOKES_V
# 62 : psp_fld_l3_quality_flags
# 63 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2
# 64 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux
# 65 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain
# 66 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum
# 67 : psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl
# 68 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4
# 69 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux
# 70 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain
# 71 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum
# 72 : psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl
# 73 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2
# 74 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_flux
# 75 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_gain
# 76 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_nsum
# 77 : psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_hl
# 78 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4
# 79 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_flux
# 80 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_gain
# 81 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_nsum
# 82 : psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_hl
# 83 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2
# 84 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux
# 85 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain
# 86 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum
# 87 : psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl
# 88 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4
# 89 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux
# 90 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain
# 91 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum
# 92 : psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl
# 93 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2
# 94 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_flux
# 95 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_gain
# 96 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_nsum
# 97 : psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_hl
# 98 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4
# 99 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_flux
# 100 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_gain
# 101 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_nsum
# 102 : psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_hl
# 103 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4
# 104 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux
# 105 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain
# 106 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum
# 107 : psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl
# 108 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4
# 109 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux
# 110 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain
# 111 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum
# 112 : psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl
# 113 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4
# 114 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain
# 115 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum
# 116 : psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl
# 117 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4
# 118 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain
# 119 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum
# 120 : psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl
# 121 : psp_fld_l3_rfs_lfr_ch0_V1V2_RTN
# 122 : psp_fld_l3_rfs_lfr_ch0_V1V2_J2000
# 123 : psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER
# 124 : psp_fld_l3_rfs_lfr_ch0_V1V2_bias
# 125 : psp_fld_l3_rfs_lfr_ch1_V3V4_RTN
# 126 : psp_fld_l3_rfs_lfr_ch1_V3V4_J2000
# 127 : psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER
# 128 : psp_fld_l3_rfs_lfr_ch1_V3V4_bias
# 129 : psp_fld_l3_rfs_lfr_solar_distance
# 130 : psp_fld_l3_rfs_lfr_position_HAE
# 131 : psp_fld_l3_rfs_lfr_position_HCI
# 132 : psp_fld_l3_rfs_lfr_position_HEE
# 133 : psp_fld_l3_rfs_lfr_position_HEEQ
# 134 : psp_fld_l3_rfs_lfr_position_HG
# 135 : psp_fld_l3_rfs_lfr_position_IAU_JUPITER
# 136 : psp_fld_l3_rfs_lfr_position_RTN
# 137 : psp_fld_l3_rfs_lfr_temperature_PA1
# 138 : psp_fld_l3_rfs_lfr_temperature_PA2
# 139 : psp_fld_l3_rfs_lfr_temperature_PA3
# 140 : psp_fld_l3_rfs_lfr_temperature_PA4
# 141 : psp_fld_l3_rfs_lfr_temperature_DCB
# 142 : psp_fld_l3_rfs_lfr_PSD_FLUX
# 143 : psp_fld_l3_rfs_lfr_PSD_SFU
# 144 : psp_fld_l3_rfs_lfr_STOKES_V
# ['psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_auto_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_hfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_hfr_solar_distance',
#  'psp_fld_l3_rfs_hfr_position_HAE',
#  'psp_fld_l3_rfs_hfr_position_HCI',
#  'psp_fld_l3_rfs_hfr_position_HEE',
#  'psp_fld_l3_rfs_hfr_position_HEEQ',
#  'psp_fld_l3_rfs_hfr_position_HG',
#  'psp_fld_l3_rfs_hfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_hfr_position_RTN',
#  'psp_fld_l3_rfs_hfr_temperature_PA1',
#  'psp_fld_l3_rfs_hfr_temperature_PA2',
#  'psp_fld_l3_rfs_hfr_temperature_PA3',
#  'psp_fld_l3_rfs_hfr_temperature_PA4',
#  'psp_fld_l3_rfs_hfr_temperature_DCB',
#  'psp_fld_l3_rfs_hfr_PSD_FLUX',
#  'psp_fld_l3_rfs_hfr_PSD_SFU',
#  'psp_fld_l3_rfs_hfr_STOKES_V',
#  'psp_fld_l3_quality_flags',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_auto_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_averages_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_flux',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_gain',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_nsum',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch0_V1V2_hl',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_hires_peaks_ch1_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_flux',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_cross_re_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_coher_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_gain',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_nsum',
#  'psp_fld_l3_rfs_lfr_phase_V1V2_V3V4_hl',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_RTN',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_J2000',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch0_V1V2_bias',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_RTN',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_J2000',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_ch1_V3V4_bias',
#  'psp_fld_l3_rfs_lfr_solar_distance',
#  'psp_fld_l3_rfs_lfr_position_HAE',
#  'psp_fld_l3_rfs_lfr_position_HCI',
#  'psp_fld_l3_rfs_lfr_position_HEE',
#  'psp_fld_l3_rfs_lfr_position_HEEQ',
#  'psp_fld_l3_rfs_lfr_position_HG',
#  'psp_fld_l3_rfs_lfr_position_IAU_JUPITER',
#  'psp_fld_l3_rfs_lfr_position_RTN',
#  'psp_fld_l3_rfs_lfr_temperature_PA1',
#  'psp_fld_l3_rfs_lfr_temperature_PA2',
#  'psp_fld_l3_rfs_lfr_temperature_PA3',
#  'psp_fld_l3_rfs_lfr_temperature_PA4',
#  'psp_fld_l3_rfs_lfr_temperature_DCB',
#  'psp_fld_l3_rfs_lfr_PSD_FLUX',
#  'psp_fld_l3_rfs_lfr_PSD_SFU',
#  'psp_fld_l3_rfs_lfr_STOKES_V']

# %%
tplot(['psp_fld_l3_rfs_hfr_auto_averages_ch0_V1V2',
       'psp_fld_l3_rfs_lfr_auto_averages_ch0_V1V2',
       'psp_fld_l3_rfs_hfr_auto_averages_ch1_V3V4',
       'psp_fld_l3_rfs_lfr_auto_averages_ch1_V3V4'
      ])

# %%
tplot(['psp_fld_l3_rfs_hfr_cross_im_V1V2_V3V4',
       'psp_fld_l3_rfs_lfr_cross_im_V1V2_V3V4'])

# %%
tplot(83)

# %%
tplot('psp_fld_l3_rfs_hfr_auto_peaks_ch0_V1V2')
