# %%
import numpy as np
import pandas as pd
from IPython.display import FileLink
from pytplot import get_data
from matplotlib import pyplot as plt
# %matplotlib tk
from matplotlib.colors import LogNorm
from sklearn.linear_model import LinearRegression
from adjustText import adjust_text

file_path = 'stereo_maven_psp_both.csv'
bursts = pd.read_csv(file_path)
print(bursts.head())
# Out:
#          Start time          End time  High frequency (Hz)  \
# 0  2021-09-21T09:43  2021-09-21T10:50             15000000
# 1  2021-10-28T15:30  2021-10-28T19:15             15000000
# 2  2022-02-15T21:55  2022-02-16T00:25             10000000
# 3  2022-05-08T02:00  2022-05-08T02:50              5000000
# 4  2022-05-17T20:37  2022-05-17T21:54              2300000
#
#    Low frequency (Hz) Notes      Start time.1        End time.1  \
# 0               40000   NaN  2021-09-21T09:40  2021-09-21T10:27
# 1               20000   NaN  2021-10-28T15:25  2021-10-28T19:15
# 2               40000   NaN  2022-02-15T21:50  2022-02-16T03:20
# 3              100000   NaN  2022-05-08T20:55  2022-05-08T21:30
# 4               70000   NaN  2022-05-17T20:30  2022-05-17T21:55
#
#    High frequency (Hz).1  Low frequency (Hz).1       Notes.1
# 0               20000000                 80000  Very obvious
# 1               20000000                 40000  Very obvious
# 2               20000000                 30000           NaN
# 3               20000000                130000           NaN
# 4               20000000                 60000           NaN

# %%
stereo = bursts.iloc[:, 0:5]
psp = bursts.iloc[:, 5:10]
psp.columns = [col.replace('.1', '') for col in psp.columns]

# %%
import radio_burst_analysis
from radio_burst_analysis import *
from importlib import reload
reload(radio_burst_analysis)
# Out:
# <module 'radio_burst_analysis' from '/Users/liu/Library/Mobile Documents/com~apple~CloudDocs/Berkeley/Research/summer_lab/compare_maven/radio_burst_analysis.py'>

# %%
stereo = calc_drift_rate(stereo)
psp = calc_drift_rate(psp)
stereo.head()
# Out:
#            Start time            End time  High frequency (Hz)  \
# 0 2021-09-21 09:43:00 2021-09-21 10:50:00             15000000
# 1 2021-10-28 15:30:00 2021-10-28 19:15:00             15000000
# 2 2022-02-15 21:55:00 2022-02-16 00:25:00             10000000
# 3 2022-05-08 02:00:00 2022-05-08 02:50:00              5000000
# 4 2022-05-17 20:37:00 2022-05-17 21:54:00              2300000
#
#    Low frequency (Hz) Notes  Frequency Change  Duration (seconds)  \
# 0               40000   NaN          14960000              4020.0
# 1               20000   NaN          14980000             13500.0
# 2               40000   NaN           9960000              9000.0
# 3              100000   NaN           4900000              3000.0
# 4               70000   NaN           2230000              4620.0
#
#    Drift Rate (Hz/s)
# 0        3721.393035
# 1        1109.629630
# 2        1106.666667
# 3        1633.333333
# 4         482.683983

# %%
make_csv(stereo, 'stereo')
make_csv(psp, 'psp')

# %%
file_path = 'maven_descending_full_clean.csv'

maven = pd.read_csv(file_path)

print(maven.head())
# Out:
#    Start Time (UTC)    End Time (UTC)   Start Energy (keV)   End Energy (keV)  \
# 0  2015-04-21T11:25  2015-04-21T12:50                   80                 20
# 1  2015-04-21T12:55  2015-04-21T14:35                    5                  2
# 2  2016-01-06T14:50  2016-01-06T16:24                  150                 20
# 3  2018-05-05T14:15  2018-05-05T14:52                   40                 20
# 4  2021-09-21T10:50  2021-09-21T12:05                   80                 20
#
#    Instrument                                              Notes
# 0         SEP   followed by SWEA descending tone; no EUV cove...
# 1        SWEA                                                NaN
# 2         SEP  SEP rapid rise in intensity at 15:10 and decli...
# 3         SEP                               no flare seen in EUV
# 4         SEP                                                NaN

# %%
maven = calc_drift_rate_energy(maven)
make_csv(maven, 'maven')

# %%
merged = merge_common_date(stereo, psp, maven, "STEREO", "PSP", "MAVEN")
# Out:
# 23-Jul-25 13:13:01: /Users/liu/Library/Mobile Documents/com~apple~CloudDocs/Berkeley/Research/summer_lab/compare_maven/radio_burst_analysis.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset1_common['Source'] = label1
#
# 23-Jul-25 13:13:01: /Users/liu/Library/Mobile Documents/com~apple~CloudDocs/Berkeley/Research/summer_lab/compare_maven/radio_burst_analysis.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset2_common['Source'] = label2
#
# 23-Jul-25 13:13:01: /Users/liu/Library/Mobile Documents/com~apple~CloudDocs/Berkeley/Research/summer_lab/compare_maven/radio_burst_analysis.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset3_common['Source'] = label3

# %%
merged = merged.drop(range(15, 21), axis=0)
merged = merged.drop(range(25, 31), axis=0)
merged = merged.drop(range(39, 47), axis=0)
merged = merged.drop(range(48, 50), axis=0)
merged
# Out:
#      Start time_stereo     End time_stereo  High frequency (Hz)_stereo  \
# 0  2021-09-21 09:43:00 2021-09-21 10:50:00                    15000000
# 1  2021-10-28 15:30:00 2021-10-28 19:15:00                    15000000
# 2  2022-02-15 21:55:00 2022-02-16 00:25:00                    10000000
# 3  2022-05-08 02:00:00 2022-05-08 02:50:00                     5000000
# 4  2022-05-17 20:37:00 2022-05-17 21:54:00                     2300000
# 5  2022-06-29 17:37:00 2022-06-29 18:00:00                     1000000
# 6  2022-06-30 05:05:00 2022-06-30 05:37:00                     6700000
# 7  2022-07-01 11:37:00 2022-07-01 12:08:00                    15000000
# 8  2022-07-22 13:05:00 2022-07-22 13:32:00                     3500000
# 9  2022-11-17 09:16:00 2022-11-17 11:24:00                    10000000
# 10 2022-12-27 17:30:00 2022-12-27 21:30:00                     7000000
# 11 2023-03-02 17:40:00 2023-03-02 19:55:00                    10000000
# 12 2023-07-11 11:20:00 2023-07-11 12:26:00                    15000000
# 13 2023-07-15 07:30:00 2023-07-15 13:35:00                    15000000
# 14 2023-09-19 20:10:00 2023-09-19 21:30:00                    15000000
# 21 2023-09-19 22:30:00 2023-09-19 23:40:00                    15000000
# 22 2024-01-10 19:00:00 2024-01-11 00:30:00                    15000000
# 23 2024-04-03 17:35:00 2024-04-03 19:00:00                     5000000
# 24 2024-05-01 18:15:00 2024-05-01 18:38:00                    15000000
# 31 2024-05-01 20:05:00 2024-05-01 20:40:00                    15000000
# 32 2024-07-10 21:10:00 2024-07-11 00:30:00                     1000000
# 33 2024-07-29 01:10:00 2024-07-29 02:46:00                    15000000
# 34 2024-07-29 01:10:00 2024-07-29 02:46:00                    15000000
# 35 2024-08-05 13:45:00 2024-08-05 21:50:00                    10000000
# 36 2024-08-07 13:45:00 2024-08-07 15:20:00                    15000000
# 37 2024-09-03 07:50:00 2024-09-03 12:00:00                     6000000
# 38 2024-09-09 00:45:00 2024-09-09 05:35:00                     3000000
# 47 2024-09-09 14:15:00 2024-09-09 16:20:00                      600000
#
#     Low frequency (Hz)_stereo                     Notes_stereo  \
# 0                       40000                              NaN
# 1                       20000                              NaN
# 2                       40000                              NaN
# 3                      100000                              NaN
# 4                       70000                              NaN
# 5                       70000                              NaN
# 6                       70000                              NaN
# 7                      100000                              NaN
# 8                       40000                              NaN
# 9                       50000                              NaN
# 10                      20000                              NaN
# 11                      20000                              NaN
# 12                      70000                              NaN
# 13                       8000                     Very obvious
# 14                      80000                              NaN
# 21                      70000                              NaN
# 22                      24000  Trigger vertical line preceding
# 23                      60000                              NaN
# 24                     150000                              NaN
# 31                     130000                              NaN
# 32                      30000                              NaN
# 33                      70000                              NaN
# 34                      70000                              NaN
# 35                      26000                     Very obvious
# 36                      50000  Trigger vertical line preceding
# 37                      30000                              NaN
# 38                      40000                              NaN
# 47                      50000                              NaN
#
#     Frequency Change_stereo  Duration (seconds)_stereo  \
# 0                  14960000                     4020.0
# 1                  14980000                    13500.0
# 2                   9960000                     9000.0
# 3                   4900000                     3000.0
# 4                   2230000                     4620.0
# 5                    930000                     1380.0
# 6                   6630000                     1920.0
# 7                  14900000                     1860.0
# 8                   3460000                     1620.0
# 9                   9950000                     7680.0
# 10                  6980000                    14400.0
# 11                  9980000                     8100.0
# 12                 14930000                     3960.0
# 13                 14992000                    21900.0
# 14                 14920000                     4800.0
# 21                 14930000                     4200.0
# 22                 14976000                    19800.0
# 23                  4940000                     5100.0
# 24                 14850000                     1380.0
# 31                 14870000                     2100.0
# 32                   970000                    12000.0
# 33                 14930000                     5760.0
# 34                 14930000                     5760.0
# 35                  9974000                    29100.0
# 36                 14950000                     5700.0
# 37                  5970000                    15000.0
# 38                  2960000                    17400.0
# 47                   550000                     7500.0
#
#     Drift Rate (Hz/s)_stereo        Date Source_stereo  ... Source_psp  \
# 0                3721.393035  2021-09-21        STEREO  ...        PSP
# 1                1109.629630  2021-10-28        STEREO  ...        PSP
# 2                1106.666667  2022-02-15        STEREO  ...        PSP
# 3                1633.333333  2022-05-08        STEREO  ...        PSP
# 4                 482.683983  2022-05-17        STEREO  ...        PSP
# 5                 673.913043  2022-06-29        STEREO  ...        PSP
# 6                3453.125000  2022-06-30        STEREO  ...        PSP
# 7                8010.752688  2022-07-01        STEREO  ...        PSP
# 8                2135.802469  2022-07-22        STEREO  ...        PSP
# 9                1295.572917  2022-11-17        STEREO  ...        PSP
# 10                484.722222  2022-12-27        STEREO  ...        PSP
# 11               1232.098765  2023-03-02        STEREO  ...        PSP
# 12               3770.202020  2023-07-11        STEREO  ...        PSP
# 13                684.566210  2023-07-15        STEREO  ...        PSP
# 14               3108.333333  2023-09-19        STEREO  ...        PSP
# 21               3554.761905  2023-09-19        STEREO  ...        PSP
# 22                756.363636  2024-01-10        STEREO  ...        PSP
# 23                968.627451  2024-04-03        STEREO  ...        PSP
# 24              10760.869565  2024-05-01        STEREO  ...        PSP
# 31               7080.952381  2024-05-01        STEREO  ...        PSP
# 32                 80.833333  2024-07-10        STEREO  ...        PSP
# 33               2592.013889  2024-07-29        STEREO  ...        PSP
# 34               2592.013889  2024-07-29        STEREO  ...        PSP
# 35                342.749141  2024-08-05        STEREO  ...        PSP
# 36               2622.807018  2024-08-07        STEREO  ...        PSP
# 37                398.000000  2024-09-03        STEREO  ...        PSP
# 38                170.114943  2024-09-09        STEREO  ...        PSP
# 47                 73.333333  2024-09-09        STEREO  ...        PSP
#
#       Start Time (UTC)      End Time (UTC)  Start Energy (keV)  \
# 0  2021-09-21 10:50:00 2021-09-21 12:05:00                  80
# 1  2021-10-28 16:55:00 2021-10-28 18:37:00                 100
# 2  2022-02-15 22:55:00 2022-02-16 01:00:00                 100
# 3  2022-05-08 05:25:00 2022-05-08 06:30:00                  80
# 4  2022-05-17 22:15:00 2022-05-18 00:30:00                  60
# 5  2022-06-29 20:45:00 2022-06-29 21:30:00                  80
# 6  2022-06-30 05:30:00 2022-06-30 08:30:00                 100
# 7  2022-07-01 16:25:00 2022-07-01 17:00:00                  80
# 8  2022-07-22 17:55:00 2022-07-22 21:05:00                  80
# 9  2022-11-17 10:20:00 2022-11-17 12:50:00                  40
# 10 2022-12-27 18:13:00 2022-12-27 19:05:00                  80
# 11 2023-03-02 18:20:00 2023-03-02 19:30:00                  50
# 12 2023-07-11 12:05:00 2023-07-11 13:20:00                  70
# 13 2023-07-15 08:45:00 2023-07-15 10:00:00                  80
# 14 2023-09-19 20:30:00 2023-09-19 22:00:00                 200
# 21 2023-09-19 23:00:00 2023-09-20 02:00:00                 100
# 22 2024-01-10 21:30:00 2024-01-10 23:30:00                  50
# 23 2024-04-03 18:20:00 2024-04-03 19:45:00                  50
# 24 2024-05-01 18:35:00 2024-05-01 19:40:00                  50
# 31 2024-05-01 22:10:00 2024-05-01 23:04:00                  80
# 32 2024-07-10 21:50:00 2024-07-10 23:30:00                 100
# 33 2024-07-29 01:20:00 2024-07-29 02:00:00                  50
# 34 2024-07-29 10:20:00 2024-07-29 12:40:00                 100
# 35 2024-08-05 14:05:00 2024-08-05 15:15:00                 150
# 36 2024-08-07 14:45:00 2024-08-07 15:45:00                  50
# 37 2024-09-03 08:35:00 2024-09-03 10:10:00                 150
# 38 2024-09-09 01:45:00 2024-09-09 04:20:00                  90
# 47 2024-09-09 14:30:00 2024-09-09 16:30:00                 150
#
#    End Energy (keV)  Instrument  \
# 0                20         SEP
# 1                20         SEP
# 2                20         SEP
# 3                20         SEP
# 4                20         SEP
# 5                20         SEP
# 6                20         SEP
# 7                20         SEP
# 8                20         SEP
# 9                20         SEP
# 10               20         SEP
# 11               20         SEP
# 12               20         SEP
# 13               20         SEP
# 14               20         SEP
# 21               20         SEP
# 22               20         SEP
# 23               20         SEP
# 24               20         SEP
# 31               23         SEP
# 32               26         SEP
# 33               20         SEP
# 34               20         SEP
# 35               20         SEP
# 36               20         SEP
# 37               20         SEP
# 38               20         SEP
# 47               20         SEP
#
#                                                 Notes  Duration (seconds)  \
# 0                                                 NaN              4500.0
# 1    leads into a hefty SEP electron event so mayb...              6120.0
# 2    leads into a SEP event so maybe flare but poo...              7500.0
# 3                                                 NaN              3900.0
# 4                                                 NaN              8100.0
# 5                                     only seen in 2F              2700.0
# 6                           on top of minor SEP event             10800.0
# 7         low intensity and on top of minor SEP event              2100.0
# 8                                very clear signature             11400.0
# 9                                                 NaN              9000.0
# 10                intense signature; end of DSW event              3120.0
# 11  anisotropic (primarily in 1R and 2F, much less...              4200.0
# 12            mostly in 1R, 2R, and 2F (little in 1F)              4500.0
# 13   mostly in 2F; trailing an M1.8 flare seen in EUV              4500.0
# 14    look flare related since abnormally high energy              5400.0
# 21                                                NaN             10800.0
# 22                                                NaN              7200.0
# 23   starts while s/c in periapse so hard to ident...              5100.0
# 24                                                dim              3900.0
# 31  primarily in 1R and 2F with little in the othe...              3240.0
# 32                                                NaN              6000.0
# 33                                                NaN              2400.0
# 34                                    strongest in 2F              8400.0
# 35  mostly isotropic although less strong in 1F in...              4200.0
# 36        mostly isotropic although less strong in 1F              3600.0
# 37  ~45 min after a M6.3 flare seen in EUV so may ...              5700.0
# 38           simultaneous to a M1.2 flare seen by EUV              9300.0
# 47                                                NaN              7200.0
#
#    Energy Change (keV) Source
# 0                   60  MAVEN
# 1                   80  MAVEN
# 2                   80  MAVEN
# 3                   60  MAVEN
# 4                   40  MAVEN
# 5                   60  MAVEN
# 6                   80  MAVEN
# 7                   60  MAVEN
# 8                   60  MAVEN
# 9                   20  MAVEN
# 10                  60  MAVEN
# 11                  30  MAVEN
# 12                  50  MAVEN
# 13                  60  MAVEN
# 14                 180  MAVEN
# 21                  80  MAVEN
# 22                  30  MAVEN
# 23                  30  MAVEN
# 24                  30  MAVEN
# 31                  57  MAVEN
# 32                  74  MAVEN
# 33                  30  MAVEN
# 34                  80  MAVEN
# 35                 130  MAVEN
# 36                  30  MAVEN
# 37                 130  MAVEN
# 38                  70  MAVEN
# 47                 130  MAVEN
#
# [28 rows x 28 columns]

# %%
merged
merged.to_csv("merged.csv", index=False)

# %%
plot_energy_change_vs_duration(maven, "MAVEN")

# %%
plot_freq_change_vs_energy_change(merged, "STEREO", "PSP")
# Out:
# Hit enter to continue:

# %%
# Power law model for stereo
plt.figure(figsize=(10, 6))
plot_power_fit(plt, merged, "stereo", 0)
plt.show()
# Out:
# Power law model for stereo: y = 3.455e+07 * x^-0.383

# %%
# Power law model for psp
plt.figure(figsize=(10, 6))
plot_power_fit(plt, merged, "psp", 0)
plt.show()
# Out:
# Power law model for psp: y = 2.188e+07 * x^-0.159

# %%
# Power law model for both overlapped
plt.figure(figsize=(10, 6))
plot_power_fit(plt, merged, "stereo", 0)
plot_power_fit(plt, merged, "psp", 1)
plt.show()
# Out:
# Power law model for stereo: y = 3.455e+07 * x^-0.383
# Power law model for psp: y = 2.188e+07 * x^-0.159

# %%
plt.figure(figsize=(10, 6))
plot_cubic_fit(plt, merged, "stereo", 0)
plt.show()
# Out:
# Cubic model for stereo: y = 9.62e+06 + 1.22e+05*x + -2.65e+03*x² + 1.17e+01*x³

# %%
plt.figure(figsize=(10, 6))
plot_cubic_fit(plt, merged, "psp", 0)
plt.show()
# Out:
# Cubic model for psp: y = 8.47e+06 + 3.63e+05*x + -5.58e+03*x² + 2.18e+01*x³

# %%
plt.figure(figsize=(10, 6))
plot_cubic_fit(plt, merged, "stereo", 0)
plot_cubic_fit(plt, merged, "psp", 1)
plt.show()
# Out:
# Cubic model for stereo: y = 9.62e+06 + 1.22e+05*x + -2.65e+03*x² + 1.17e+01*x³
# Cubic model for psp: y = 8.47e+06 + 3.63e+05*x + -5.58e+03*x² + 2.18e+01*x³
