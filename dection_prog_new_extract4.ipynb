# %%
from detection_helper import *

# %%
times_arr, freq_arr, data_arr = return_arr('2023-08-19', '2023-08-20')
freq_log, freq_log_exp, data_arr_log = convert_data_log(freq_arr, data_arr)
bmap = bmap_row_mean_loop_new(times_arr=times_arr, full_data=data_arr_log, min_duration=1)
plot_bmap(times_arr, freq_log_exp, bmap)
# Out:
# 10-Feb-26 22:15:33: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 10-Feb-26 22:15:34: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20230819_v03.cdf
# 10-Feb-26 22:15:34: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 10-Feb-26 22:15:34: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20230819_v03.cdf
# 10-Feb-26 22:15:34: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 10-Feb-26 22:15:35: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20230819_v03.cdf
# 10-Feb-26 22:15:35: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 10-Feb-26 22:15:35: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20230819_v03.cdf

# %%
plot_spectrum(times_arr, freq_log_exp, data_arr_log)

# %%
lines = all_lines_day(bmap, times_arr, freq_log_exp, data_arr_log)
plot_bmap(times_arr, freq_log_exp, bmap, lines)

# %%
times_arr2, freq_arr2, data_arr2 = return_arr('2023-10-02', '2023-10-03')
# Out:
# 10-Feb-26 22:15:48: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 10-Feb-26 22:15:48: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20231002_v03.cdf
# 10-Feb-26 22:15:48: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 10-Feb-26 22:15:48: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20231002_v03.cdf
# 10-Feb-26 22:15:48: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 10-Feb-26 22:15:49: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20231002_v03.cdf
# 10-Feb-26 22:15:49: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 10-Feb-26 22:15:49: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20231002_v03.cdf

# %%
data_arr2.shape
# Out:
# (24718, 128)

# %%
freq_log2, freq_log_exp2, data_arr_log2 = convert_data_log(freq_arr2, data_arr2)
plot_spectrum(times_arr2, freq_log_exp2, data_arr_log2)
bmap2 = bmap_row_mean_loop_new(times_arr2, data_arr_log2, min_duration=1)
plot_bmap(times_arr2, freq_log_exp2, bmap2)

# %%
longest_line_low2, longest_line_high2 = plot_line_slice(bmap2, times_arr2, freq_log_exp2, data_arr_log2)
lines2 = all_lines_day(bmap2, times_arr2, freq_log_exp2, data_arr_log2)
plot_bmap(times_arr2, freq_log_exp2, bmap2, lines2)

# %%
times_arr3, freq_arr3, data_arr3 = return_arr('2023-07-01', '2023-07-02')
freq_log3, freq_log_exp3, data_arr_log3 = convert_data_log(freq_arr3, data_arr3)
bmap3 = bmap_row_mean_loop_new(times_arr3, data_arr_log3, min_duration=1)
lines3 = all_lines_day(bmap3, times_arr3, freq_log_exp3, data_arr_log3)
plot_bmap(times_arr3, freq_log_exp3, bmap3, lines3)
# Out:
# 10-Feb-26 22:15:59: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 10-Feb-26 22:16:00: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20230701_v03.cdf
# 10-Feb-26 22:16:00: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_hfr/2023/
# 10-Feb-26 22:16:00: File is current: psp_data/fields/l3/rfs_hfr/2023/psp_fld_l3_rfs_hfr_20230701_v03.cdf
# 10-Feb-26 22:16:00: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 10-Feb-26 22:16:00: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20230701_v03.cdf
# 10-Feb-26 22:16:00: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l3/rfs_lfr/2023/
# 10-Feb-26 22:16:01: File is current: psp_data/fields/l3/rfs_lfr/2023/psp_fld_l3_rfs_lfr_20230701_v03.cdf
